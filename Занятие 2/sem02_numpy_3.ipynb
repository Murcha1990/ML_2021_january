# %% [markdown]
# # Семинар 2

# %% [markdown]
# - про Jupyter Notebook: https://devpractice.ru/python-lesson-6-work-in-jupyter-notebook/

# %% [markdown]
# ## numpy

# %% [markdown]
# - документация: http://www.numpy.org/

# %% [markdown]
# Библиотека numpy является удобным инструментом для работы с многомерными массивами с возможностью векторизации вычислений. Рассмотрим базовые вещи, которые можно делать с помощью нее.

# %%
import numpy as np

# %%
vec = np.array([[1, 2], [3, 4], [5, 6]])

# %%
vec

# %%
print(vec)

# %% [markdown]
# С чем мы работаем?

# %%
vec.dtype

# %%
type(vec)

# %% [markdown]
# Размер массива:

# %%
vec.shape

# %% [markdown]
# Число осей:

# %%
vec.ndim

# %% [markdown]
# У некоторых функций бывает параметр `axis`, который позволяет применить эту функцию по разным осям - в данном случае, по строкам или столбцам:

# %%
np.sum(vec)

# %%
np.sum(vec, axis=0)

# %%
np.sum(vec, axis=1)

# %%
vec.sum()

# %% [markdown]
# Транспонируем массив:

# %%
vec.T

# %%
vec.transpose()

# %% [markdown]
# Обратите внимание, что переменная `vec` не поменялась!

# %%
vec

# %%
vec.shape

# %% [markdown]
# Размеры массивов можно менять:

# %%
vec.reshape(2, 3)

# %%
vec.reshape(-1, 3)

# %%
vec.reshape(2, -1)

# %%
vec.reshape(-1)

# %%
vec

# %% [markdown]
# Индексирование:

# %%
vec[:, 1]

# %%
vec[2, :]

# %%
vec[1:2, 0]

# %%
vec[:2, :]

# %%
vec[::2, :]

# %% [markdown]
# Булевы массивы:

# %%
is_even = vec % 2 == 0
print(is_even)

# %%
np.sum(is_even)

# %% [markdown]
# Булевы массивы позволяют вытаскивать элементы с True из массива того-же размера

# %%
vec[vec % 3 == 0]

# %% [markdown]
# Иногда бывает полезно создавать специфичные массивы. Массив из нулей:

# %%
np.zeros((2, 3))

# %% [markdown]
# Массив из единиц:

# %%
np.ones((3, 2))

# %% [markdown]
# Единичная матрица:

# %%
np.identity(5)

# %% [markdown]
# Массивы можно объединять:

# %%
vec

# %%
np.hstack((vec, np.zeros(vec.shape)))

# %%
np.vstack((vec, np.zeros(vec.shape)))

# %% [markdown]
# И, наконец - арифметические операции!

# %%
vec + 1

# %%
vec * 2

# %%
vec ** 2

# %%
vec + vec ** 2

# %%
vec * vec ** 2 #поэлементное умножение

# %%
np.sin(vec)

# %% [markdown]
# Матричное умножение:

# %%
vec.dot(vec ** 2)

# %%
vec.dot((vec ** 2).T)

# %%
# ?np.cross

# %%
vec @ (vec ** 2).T

# %%
vec * vec # поэлеметное, но не матричное умножение!

# %% [markdown]
# Broadcasting:
# https://docs.scipy.org/doc/numpy-1.15.0/user/basics.broadcasting.html

# %%
vec

# %%
np.arange(3)

# %%
vec + np.arange(3)

# %%
np.arange(3).reshape(3, 1)

# %%
vec + np.arange(2).reshape(1, 2)

# %%
vec + np.arange(3).reshape(3, 1)

# %% [markdown]
# Генерация случайных чисел:

# %%
np.random.rand(2, 3)

# %%
np.random.seed(3)
np.random.rand(2, 3)

# %%
np.random.randn(3, 2) #standard normal dist.

# %%
np.random.normal(2, 1, size=(3,2))

# %%
np.random.randint(5, 10, size=3)

# %% [markdown]
# Почему вообще используют `numpy`?

# %%
n = 300
A = np.random.rand(n, n)
B = np.random.rand(n, n)

# %%
# %%time
C = np.zeros((n, n))
for i in range(n):
    for j in range(n):
        for k in range(n):
            C[i, j] += A[i, k] * B[k, j]

# %%
# %%time
C = A @ B

# %% [markdown]
# Операция присваивания

# %%
a = vec
a

# %%
vec[0,1] = 5
vec

# %%
a

# %%
b = vec.copy()

vec[2,1] = 10
vec

# %%
b

# %% [markdown]
# ### Что ещё можно делать

# %% [markdown]
# Разворачивать массив

# %%
v = np.random.randint(5, 10, size=5)
v

# %%
v[::-1]

# %% [markdown]
# Читать информацию о функции

# %%
# ?np.random.randint

# %% [markdown]
# Перемешивать элементы массива

# %%
np.random.permutation(v)

# %% [markdown]
# И многое другое...

# %% [markdown]
# ### Задания для самостоятельного решения

# %% [markdown]
# 1. Выведите квадраты первых десяти натуральных чисел

# %%
#your code here

# %% [markdown]
# 2. Выведите элементы массива, кратные трем.

# %%
v = np.random.randint(5, 10, size=5)

#your code here

# %% [markdown]
# 3. Найдите максимальный нечетный элемент в массиве.

# %%
#your code here

# %% [markdown]
# 4. Замените все нечетные элементы массива на ваше любимое число.

# %%
#your code here

# %% [markdown]
# 5. Создайте массив первых n нечетных чисел, записанных в порядке убывания. Например, если `n=5`, то ответом будет `array([9, 7, 5, 3, 1])`. *Функции, которые могут пригодиться при решении: `.arange()`*

# %%
#your code here

# %% [markdown]
# 6. Вычислите самое близкое и самое дальнее числа к данному в рассматриваемом массиве чисел. Например, если на вход поступают массив `array([5, 1, 2, 9, 7])` и число 1.33, то ответом будет `(1, 9)`. _Функции, которые могут пригодиться при решении: `.abs()`, `.argmax()`, `.argmin()`_

# %%
#your code here

# %% [markdown]
# 7*. Вычислите первообразную заданного полинома (в качестве константы возьмите ваше любимое число). Например, если на вход поступает массив коэффициентов `array([4, 6, 0, 1])`, что соответствует полиному $4x^3 + 6x^2 + 1$, на выходе получается массив коэффициентов `array([1, 2, 0, 1, -2])`, соответствующий полиному $x^4 + 2x^3 + x - 2$. _Функции, которые могут пригодиться при решении: `.append()`_

# %%
#your code here

# %% [markdown]
# 8*. Посчитайте первую производную для заданного полинома в заданной точке.

# %%
#your code here
